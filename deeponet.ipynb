# %% [markdown]
# # DeepONet
#
# ## Linear elastic cantilever beam under displacement boundary conditions

# %% [markdown]
# Governing equation: $-\nabla\cdot \sigma = 0$.
#
# <img src="https://github.com/DesignSafe-Training/deeponet/blob/main/Schematic.png?raw=true" width=1150 height=550 />

# %% [markdown]
# ### Install packages

# %%
# !pip install jax[cuda] numpy scikit-learn flax scipy termcolor tqdm matplotlib seaborn --user
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /home/jovyan/work/.local/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: flax in /home/jovyan/work/.local/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: scipy in /home/jovyan/work/.local/lib/python3.10/site-packages (1.14.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: tqdm in /home/jovyan/work/.local/lib/python3.10/site-packages (4.67.0)
# Requirement already satisfied: matplotlib in /home/jovyan/work/.local/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: seaborn in /home/jovyan/work/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: jax[cuda] in /home/jovyan/work/.local/lib/python3.10/site-packages (0.4.35)
# Requirement already satisfied: jaxlib<=0.4.35,>=0.4.34 in /home/jovyan/work/.local/lib/python3.10/site-packages (from jax[cuda]) (0.4.34)
# Requirement already satisfied: ml-dtypes>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from jax[cuda]) (0.4.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax[cuda]) (3.3.0)
# Requirement already satisfied: jax-cuda12-plugin<=0.4.35,>=0.4.34 in /home/jovyan/work/.local/lib/python3.10/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (0.4.35)
# Requirement already satisfied: joblib>=1.2.0 in /home/jovyan/work/.local/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/jovyan/work/.local/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: msgpack in /home/jovyan/work/.local/lib/python3.10/site-packages (from flax) (1.1.0)
# Requirement already satisfied: optax in /home/jovyan/work/.local/lib/python3.10/site-packages (from flax) (0.2.3)
# Requirement already satisfied: orbax-checkpoint in /home/jovyan/work/.local/lib/python3.10/site-packages (from flax) (0.8.0)
# Requirement already satisfied: tensorstore in /home/jovyan/work/.local/lib/python3.10/site-packages (from flax) (0.1.67)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax) (13.8.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/dist-packages (from flax) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax) (6.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jovyan/work/.local/lib/python3.10/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/jovyan/work/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jovyan/work/.local/lib/python3.10/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jovyan/work/.local/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/jovyan/work/.local/lib/python3.10/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jovyan/work/.local/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/jovyan/work/.local/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: jax-cuda12-pjrt==0.4.35 in /home/jovyan/work/.local/lib/python3.10/site-packages (from jax-cuda12-plugin<=0.4.35,>=0.4.34->jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (0.4.35)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.3.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.3.101)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12>=12.1.105 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.3.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.3.101)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.1 in /home/jovyan/work/.local/lib/python3.10/site-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (9.5.1.17)
# Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (11.0.12.1)
# Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (11.5.4.101)
# Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.2.0.103)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.35,>=0.4.34; extra == "cuda"->jax[cuda]) (12.3.101)
# Requirement already satisfied: pytz>=2020.1 in /home/jovyan/work/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jovyan/work/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax) (2.18.0)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from optax->flax) (2.1.0)
# Requirement already satisfied: chex>=0.1.86 in /home/jovyan/work/.local/lib/python3.10/site-packages (from optax->flax) (0.1.87)
# Requirement already satisfied: etils[epy] in /home/jovyan/work/.local/lib/python3.10/site-packages (from optax->flax) (1.10.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax) (4.25.4)
# Requirement already satisfied: humanize in /home/jovyan/work/.local/lib/python3.10/site-packages (from orbax-checkpoint->flax) (4.11.0)
# Requirement already satisfied: toolz>=0.9.0 in /home/jovyan/work/.local/lib/python3.10/site-packages (from chex>=0.1.86->optax->flax) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax) (0.1.2)
# Requirement already satisfied: fsspec in /home/jovyan/work/.local/lib/python3.10/site-packages (from etils[epath,epy]->orbax-checkpoint->flax) (2024.10.0)
# Requirement already satisfied: importlib_resources in /home/jovyan/work/.local/lib/python3.10/site-packages (from etils[epath,epy]->orbax-checkpoint->flax) (6.4.5)
# Requirement already satisfied: zipp in /home/jovyan/work/.local/lib/python3.10/site-packages (from etils[epath,epy]->orbax-checkpoint->flax) (3.20.2)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# ### Fetch geometry and trained model data

# %%
# !mkdir -p deeponet_results
# !wget https://github.com/DesignSafe-Training/deeponet/raw/refs/heads/main/model_params_best.pkl -P deeponet_results/

# %%
# !wget https://github.com/DesignSafe-Training/deeponet/raw/refs/heads/main/cantilever_beam_deflection.mat

# %%
import jax.numpy as jnp
import numpy.random as npr
from jax import jit, grad, vmap
from jax.example_libraries.optimizers import adam
from jax import value_and_grad
from functools import partial
from jax import jacfwd, jacrev
import jax.nn as jnn
import math
from jax import random
import jax
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn import metrics
from flax import linen as nn
import sklearn.metrics
from scipy.interpolate import griddata
from matplotlib.colors import SymLogNorm
from tqdm import tqdm

import os
import time
from termcolor import colored
from scipy.io import loadmat
import scipy.io as io
import pickle

import sys
sys.path.append("../..")

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 9})
import seaborn as sns
sns.set_style("white")
sns.set_style("ticks")

import warnings
warnings.filterwarnings("ignore")

# Check where gpu is enable or not
from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# gpu

# %%
save = True
resultdir = os.path.join(os.getcwd(), 'deeponet_results')
if save == True:
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

# %% [markdown]
# ### Data

# %%
# Load the data
data = loadmat('./cantilever_beam_deflection.mat') # Load the .mat file
print("Shape of loading matrix (Input Function):", data['loading'].shape) # Input to deeponet - varying loading conditions
print("Shape of Displacement-X matrix (Output Function):", data['disp_x'].shape) # Output from deeponet - The corresponding deflection in X-direction
print("Shape of Displacement-Y matrix (Output Function):", data['disp_y'].shape) # Output from deeponet - The corresponding deflection in Y-direction

# Convert NumPy arrays to tensors
inputs = jnp.array(data['loading'])
sensor_loc = jnp.array(data['sensor_loc_loading'])
outputs_x = jnp.array(data['disp_x'])
outputs_y = jnp.array(data['disp_y'])
grid_x = data['coord_x'].T
grid_y = data['coord_y'].T
grid = jnp.concatenate([grid_x, grid_y], axis=1, dtype=None)
print("Shape of grid for the cantilever beam:", grid.shape) # (n,2)

num_train = 800
num_test = 200
# Split the data into training (800) and testing (200) samples
inputs_train, inputs_test, outputs_x_train, outputs_x_test, outputs_y_train, outputs_y_test = train_test_split(inputs, outputs_x, outputs_y, test_size=200, random_state=0)
print("Shape of loading matrix used for training:", inputs_train.shape)
print("Shape of x-displacement matrix corresponding to the training loads:", outputs_x_train.shape)
print("Shape of y-displacement matrix corresponding to the training loads:", outputs_y_train.shape)
print("Shape of loading matrix used for testing:", inputs_test.shape)
print("Shape of x-displacement matrix corresponding to the testing loads:", outputs_x_test.shape)
print("Shape of y-displacement matrix corresponding to the testing loads:", outputs_y_test.shape)
print('#'*100)
# Out:
# Shape of loading matrix (Input Function): (1000, 100)
# Shape of Displacement-X matrix (Output Function): (1000, 1314)
# Shape of Displacement-Y matrix (Output Function): (1000, 1314)
# Shape of grid for the cantilever beam: (1314, 2)
# Shape of loading matrix used for training: (800, 100)
# Shape of x-displacement matrix corresponding to the training loads: (800, 1314)
# Shape of y-displacement matrix corresponding to the training loads: (800, 1314)
# Shape of loading matrix used for testing: (200, 100)
# Shape of x-displacement matrix corresponding to the testing loads: (200, 1314)
# Shape of y-displacement matrix corresponding to the testing loads: (200, 1314)
# ####################################################################################################

# %% [markdown]
# ### Define a Neural Network

# %%
# network parameters.
p = 100 # Number of output neurons in both the branch and trunk net.
num_sensor = inputs_train.shape[1]
input_neurons_branch = num_sensor
input_neurons_trunk = grid.shape[1]
layer_sizes_b = [input_neurons_branch] + [100]*6 + [2*p]
layer_sizes_t = [input_neurons_trunk] + [100]*6 + [2*p]

bs = 450 # batch size
n_epochs = 200000

# %%
# Initialize the Glorot (Xavier) normal distribution for weight initialization
initializer = jax.nn.initializers.glorot_normal()

def init_glorot_params(layer_sizes, key = random.PRNGKey(0)):
    """
    Initialize the parameters of the neural network using Glorot (Xavier) initialization.

    Args:
    layer_sizes (list): List of integers representing the size of each layer.
    key (PRNGKey): Random number generator key for reproducibility.

    Returns:
    list: List of tuples, each containing weights and biases for a layer.
    """
    return [(initializer(key, (m, n), jnp.float32), jnp.zeros(n))
            for m, n, in zip(layer_sizes[:-1], layer_sizes[1:])]

params_branch = init_glorot_params(layer_sizes=layer_sizes_b)
params_trunk = init_glorot_params(layer_sizes=layer_sizes_t)
params= (params_branch, params_trunk)

# Initialize the Adam optimizer
opt_init, opt_update, get_params = adam(step_size=1e-3, b1=0.9, b2=0.999, eps=1e-08)
opt_state = opt_init(params)

# %%
def BranchNet(params, x):
    """
    Implement the branch network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (array): Input to the branch network.

    Returns:
    array: Output of the branch network.
    """
    def single_forward(params, x):
        for w, b in params:
            outputs = jnp.dot(x, w) + b
            x = jnn.silu(outputs)
        return outputs

    return vmap(partial(single_forward, params))(x)

def TrunkNet(params, x, y):
    """
    Implement the trunk network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (float): First input to the trunk network.
    t (float): Second input to the trunk network.

    Returns:
    array: Output of the trunk network.
    """
    inputs = jnp.array([x, y])
    for w, b in params:
        outputs = jnp.dot(inputs, w) + b
        inputs = jnn.silu(outputs)
    return outputs

@jit
def DeepONet(params, branch_inputs, trunk_inputs):
    """
    Implement the complete DeepONet architecture.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.

    Returns:
    array: Output of the DeepONet.
    """
    params_branch, params_trunk = params
    branch_outputs = lambda x: BranchNet(params_branch, x)
    b_out = branch_outputs(branch_inputs)
    trunk_output = lambda x, y: TrunkNet(params_trunk, x, y)
    t_out = vmap(trunk_output)(trunk_inputs[:,0],trunk_inputs[:,1])
    results_x = jnp.einsum('ik, lk -> il',b_out[:,0:p], t_out[:,0:p])
    results_y = jnp.einsum('ik, lk -> il',b_out[:,p:2*p], t_out[:,p:2*p])
    return results_x, results_y

# %%
def objective(params, branch_inputs, trunk_inputs, target_values_x, target_values_y):
    """
    Define the objective function (loss function) for training.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values to compare against.

    Returns:
    float: Mean squared error loss.
    """

    predictions_x, predictions_y = DeepONet(params, branch_inputs, trunk_inputs)
    loss_mse = jnp.mean((predictions_x - target_values_x)**2) + jnp.mean((predictions_y - target_values_y)**2)
    return loss_mse


# Adam optimizer
@jit
def network_update(params, branch_inputs, trunk_inputs, target_values_x, target_values_y, opt_state):
    """
    Compute the gradient for a batch and update the parameters.

    Args:
    params (tuple): Current network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values.
    opt_state: Current state of the optimizer.

    Returns:
    tuple: Updated parameters, updated optimizer state, and current loss value.
    """
    value, grads = value_and_grad(objective)(params, branch_inputs, trunk_inputs, target_values_x, target_values_y)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, value

# %%
def save_model_params(params, resultdir, filename='model_params.pkl'):
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

    save_path = os.path.join(resultdir, filename)
    with open(save_path, 'wb') as f:
        pickle.dump(params, f)

def load_model_params(resultdir, filename='model_params.pkl'):
    load_path = os.path.join(resultdir, filename)
    with open(load_path, 'rb') as f:
        params = pickle.load(f)
    return params

# Saving
if save:
    save_model_params(params, resultdir)

# Loading (uncomment when needed)
# model_params = load_model_params(resultdir)

# %% [markdown]
# ### Training

# %%
num_samples = len(inputs_train)

# Training of DeepONet
start = time.time()  # start time of training
best_test_mse = float('inf')  # Initialize with infinity

print("------------- START TRAINING -------------")
# Save initial model at 0th iteration

save_model_params(params, resultdir, filename='model_params_best.pkl')
print("Saved initial model at iteration 0")
iteration_list, loss_list, test_loss_list = [], [], []

# Create tqdm progress bar
pbar = tqdm(range(n_epochs), desc='Training', ncols=175)

for iteration in pbar:
    # Shuffle and batch data
    indices = jax.random.permutation(jax.random.PRNGKey(0), num_samples)
    batch_index = indices[0:bs]
    inputs_train_shuffled = inputs_train[batch_index]
    outputs_x_train_shuffled = outputs_x_train[batch_index]
    outputs_y_train_shuffled = outputs_y_train[batch_index]
    # Set target values
    target_values_x = outputs_x_train_shuffled
    target_values_y = outputs_y_train_shuffled
    branch_inputs = inputs_train_shuffled
    trunk_inputs = grid
    # Update network
    params, opt_state, value = network_update(
        params, branch_inputs, trunk_inputs,
        target_values_x, target_values_y, opt_state
    )
    # Evaluate and save model every 1000 iterations
    if iteration % 1000 == 0:
        predictions_x, predictions_y = DeepONet(params, branch_inputs, trunk_inputs)
        test_mse = jnp.mean((predictions_x - target_values_x)**2) + \
                   jnp.mean((predictions_y - target_values_y)**2)
        current_loss = objective(params, branch_inputs, trunk_inputs,
                               target_values_x, target_values_y)
        # Update best model if needed
        if test_mse < best_test_mse:
            best_test_mse = test_mse
            save_model_params(params, resultdir, filename='model_params_best.pkl')
            desc = f'Training (New Best: {test_mse:.2e} @ iter {iteration})'
            pbar.set_description(desc)
        # Calculate training time
        finish = time.time() - start
        # Update progress bar description with metrics
        pbar.set_postfix({
            'Train Loss': f'{current_loss:.2e}',
            'Test Loss': f'{test_mse:.2e}',
            'Best Test': f'{best_test_mse:.2e}',
            'Time': f'{finish:.2e}s'
        })

    # Store metrics for plotting
    iteration_list.append(iteration)
    loss_list.append(objective(params, branch_inputs, trunk_inputs, target_values_x, target_values_y))
    test_loss_list.append(test_mse)

if save:
    np.save(os.path.join(resultdir, 'iteration_list.npy'), np.asarray(iteration_list))
    np.save(os.path.join(resultdir, 'loss_list.npy'), np.asarray(loss_list))
    np.save(os.path.join(resultdir, 'test_loss_list.npy'), np.asarray(test_loss_list))

# Plotting code remains the same
plt.figure()
plt.plot(iteration_list, loss_list, '-g', label='Training loss')
plt.plot(iteration_list, test_loss_list, '-b', label='Test loss')
plt.yscale("log")
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()
if save:
    plt.savefig(os.path.join(resultdir, 'loss_plot.pdf'))
# end timer
finish = time.time() - start
print("Time (sec) to complete:\n" + str(finish))
# Out:
# ------------- START TRAINING -------------
# Saved initial model at iteration 0
# New best model saved at iteration 0 with test MSE: 0.0390862
# Iteration:   0, Train loss: 0.0390862, Test loss: 0.0390862, Best test loss: 0.0390862, Time: 2.12
# New best model saved at iteration 1000 with test MSE: 0.0027250
# Iteration: 1000, Train loss: 0.0027250, Test loss: 0.0027250, Best test loss: 0.0027250, Time: 9.67
# New best model saved at iteration 2000 with test MSE: 0.0007205
# Iteration: 2000, Train loss: 0.0007205, Test loss: 0.0007205, Best test loss: 0.0007205, Time: 16.55
# New best model saved at iteration 3000 with test MSE: 0.0003108
# Iteration: 3000, Train loss: 0.0003108, Test loss: 0.0003108, Best test loss: 0.0003108, Time: 23.31
# New best model saved at iteration 4000 with test MSE: 0.0002083
# Iteration: 4000, Train loss: 0.0002083, Test loss: 0.0002083, Best test loss: 0.0002083, Time: 30.40
# New best model saved at iteration 5000 with test MSE: 0.0001633
# Iteration: 5000, Train loss: 0.0001633, Test loss: 0.0001633, Best test loss: 0.0001633, Time: 37.24
# New best model saved at iteration 6000 with test MSE: 0.0001012
# Iteration: 6000, Train loss: 0.0001012, Test loss: 0.0001012, Best test loss: 0.0001012, Time: 44.31
# New best model saved at iteration 7000 with test MSE: 0.0000861
# Iteration: 7000, Train loss: 0.0000861, Test loss: 0.0000861, Best test loss: 0.0000861, Time: 51.01
# New best model saved at iteration 8000 with test MSE: 0.0000759
# Iteration: 8000, Train loss: 0.0000759, Test loss: 0.0000759, Best test loss: 0.0000759, Time: 57.87
# New best model saved at iteration 9000 with test MSE: 0.0000620
# Iteration: 9000, Train loss: 0.0000620, Test loss: 0.0000620, Best test loss: 0.0000620, Time: 64.67
# New best model saved at iteration 10000 with test MSE: 0.0000543
# Iteration: 10000, Train loss: 0.0000543, Test loss: 0.0000543, Best test loss: 0.0000543, Time: 71.39
# New best model saved at iteration 11000 with test MSE: 0.0000367
# Iteration: 11000, Train loss: 0.0000367, Test loss: 0.0000367, Best test loss: 0.0000367, Time: 78.15
# New best model saved at iteration 12000 with test MSE: 0.0000302
# Iteration: 12000, Train loss: 0.0000302, Test loss: 0.0000302, Best test loss: 0.0000302, Time: 84.93
# Iteration: 13000, Train loss: 0.0000326, Test loss: 0.0000326, Best test loss: 0.0000302, Time: 92.48
# New best model saved at iteration 14000 with test MSE: 0.0000214
# Iteration: 14000, Train loss: 0.0000214, Test loss: 0.0000214, Best test loss: 0.0000214, Time: 99.62
# Iteration: 15000, Train loss: 0.0000313, Test loss: 0.0000313, Best test loss: 0.0000214, Time: 106.46
# New best model saved at iteration 16000 with test MSE: 0.0000163
# Iteration: 16000, Train loss: 0.0000163, Test loss: 0.0000163, Best test loss: 0.0000163, Time: 113.31
# New best model saved at iteration 17000 with test MSE: 0.0000151
# Iteration: 17000, Train loss: 0.0000151, Test loss: 0.0000151, Best test loss: 0.0000151, Time: 120.27
# New best model saved at iteration 18000 with test MSE: 0.0000144
# Iteration: 18000, Train loss: 0.0000144, Test loss: 0.0000144, Best test loss: 0.0000144, Time: 127.17
# Iteration: 19000, Train loss: 0.0000162, Test loss: 0.0000162, Best test loss: 0.0000144, Time: 133.93
# New best model saved at iteration 20000 with test MSE: 0.0000124
# Iteration: 20000, Train loss: 0.0000124, Test loss: 0.0000124, Best test loss: 0.0000124, Time: 140.86
# New best model saved at iteration 21000 with test MSE: 0.0000078
# Iteration: 21000, Train loss: 0.0000078, Test loss: 0.0000078, Best test loss: 0.0000078, Time: 148.12
# Iteration: 22000, Train loss: 0.0000110, Test loss: 0.0000110, Best test loss: 0.0000078, Time: 155.40
# New best model saved at iteration 23000 with test MSE: 0.0000050
# Iteration: 23000, Train loss: 0.0000050, Test loss: 0.0000050, Best test loss: 0.0000050, Time: 162.64
# New best model saved at iteration 24000 with test MSE: 0.0000035
# Iteration: 24000, Train loss: 0.0000035, Test loss: 0.0000035, Best test loss: 0.0000035, Time: 169.85
# Iteration: 25000, Train loss: 0.0000092, Test loss: 0.0000092, Best test loss: 0.0000035, Time: 177.03
# Iteration: 26000, Train loss: 0.0000044, Test loss: 0.0000044, Best test loss: 0.0000035, Time: 184.34
# New best model saved at iteration 27000 with test MSE: 0.0000031
# Iteration: 27000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000031, Time: 191.29
# New best model saved at iteration 28000 with test MSE: 0.0000027
# Iteration: 28000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000027, Time: 198.01
# Iteration: 29000, Train loss: 0.0000042, Test loss: 0.0000042, Best test loss: 0.0000027, Time: 205.32
# Iteration: 30000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000027, Time: 212.64
# New best model saved at iteration 31000 with test MSE: 0.0000025
# Iteration: 31000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000025, Time: 219.98
# Iteration: 32000, Train loss: 0.0000038, Test loss: 0.0000038, Best test loss: 0.0000025, Time: 227.34
# Iteration: 33000, Train loss: 0.0000029, Test loss: 0.0000029, Best test loss: 0.0000025, Time: 234.79
# Iteration: 34000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000025, Time: 242.01
# New best model saved at iteration 35000 with test MSE: 0.0000024
# Iteration: 35000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000024, Time: 249.14
# New best model saved at iteration 36000 with test MSE: 0.0000021
# Iteration: 36000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 256.77
# New best model saved at iteration 37000 with test MSE: 0.0000021
# Iteration: 37000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000021, Time: 264.23
# Iteration: 38000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000021, Time: 271.68
# Iteration: 39000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000021, Time: 279.22
# Iteration: 40000, Train loss: 0.0000031, Test loss: 0.0000031, Best test loss: 0.0000021, Time: 286.68
# Iteration: 41000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000021, Time: 294.03
# New best model saved at iteration 42000 with test MSE: 0.0000016
# Iteration: 42000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000016, Time: 301.45
# Iteration: 43000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000016, Time: 308.75
# New best model saved at iteration 44000 with test MSE: 0.0000013
# Iteration: 44000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000013, Time: 316.28
# Iteration: 45000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000013, Time: 323.76
# Iteration: 46000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000013, Time: 330.61
# Iteration: 47000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000013, Time: 337.92
# New best model saved at iteration 48000 with test MSE: 0.0000009
# Iteration: 48000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000009, Time: 345.38
# Iteration: 49000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000009, Time: 352.44
# Iteration: 50000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000009, Time: 359.45
# Iteration: 51000, Train loss: 0.0000067, Test loss: 0.0000067, Best test loss: 0.0000009, Time: 366.35
# Iteration: 52000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000009, Time: 373.58
# New best model saved at iteration 53000 with test MSE: 0.0000008
# Iteration: 53000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000008, Time: 381.21
# New best model saved at iteration 54000 with test MSE: 0.0000008
# Iteration: 54000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000008, Time: 388.84
# Iteration: 55000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000008, Time: 396.19
# Iteration: 56000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000008, Time: 403.56
# New best model saved at iteration 57000 with test MSE: 0.0000007
# Iteration: 57000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 410.76
# Iteration: 58000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 417.96
# Iteration: 59000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000007, Time: 425.37
# Iteration: 60000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000007, Time: 432.78
# Iteration: 61000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000007, Time: 440.09
# New best model saved at iteration 62000 with test MSE: 0.0000007
# Iteration: 62000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 447.23
# Iteration: 63000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000007, Time: 454.53
# New best model saved at iteration 64000 with test MSE: 0.0000006
# Iteration: 64000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000006, Time: 461.73
# Iteration: 65000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000006, Time: 468.78
# Iteration: 66000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000006, Time: 475.82
# Iteration: 67000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000006, Time: 482.93
# Iteration: 68000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000006, Time: 490.06
# New best model saved at iteration 69000 with test MSE: 0.0000006
# Iteration: 69000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000006, Time: 497.41
# Iteration: 70000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000006, Time: 504.64
# New best model saved at iteration 71000 with test MSE: 0.0000005
# Iteration: 71000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 511.74
# Iteration: 72000, Train loss: 0.0000100, Test loss: 0.0000100, Best test loss: 0.0000005, Time: 518.82
# Iteration: 73000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000005, Time: 525.91
# Iteration: 74000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000005, Time: 532.85
# Iteration: 75000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 540.19
# New best model saved at iteration 76000 with test MSE: 0.0000005
# Iteration: 76000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 547.46
# Iteration: 77000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000005, Time: 554.50
# Iteration: 78000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000005, Time: 561.47
# Iteration: 79000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 568.59
# Iteration: 80000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000005, Time: 575.89
# Iteration: 81000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 582.98
# New best model saved at iteration 82000 with test MSE: 0.0000005
# Iteration: 82000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 590.17
# Iteration: 83000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000005, Time: 597.27
# Iteration: 84000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000005, Time: 604.56
# Iteration: 85000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000005, Time: 611.81
# Iteration: 86000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000005, Time: 619.19
# Iteration: 87000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 626.27
# Iteration: 88000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 633.61
# Iteration: 89000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 640.84
# Iteration: 90000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000005, Time: 647.90
# Iteration: 91000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 654.91
# Iteration: 92000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000005, Time: 662.04
# New best model saved at iteration 93000 with test MSE: 0.0000004
# Iteration: 93000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 669.22
# Iteration: 94000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 676.37
# Iteration: 95000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 683.59
# Iteration: 96000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000004, Time: 690.70
# Iteration: 97000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000004, Time: 697.76
# Iteration: 98000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000004, Time: 704.75
# New best model saved at iteration 99000 with test MSE: 0.0000004
# Iteration: 99000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 711.63
# Iteration: 100000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000004, Time: 723.55
# Iteration: 101000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000004, Time: 730.89
# Iteration: 102000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000004, Time: 738.28
# Iteration: 103000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000004, Time: 745.61
# Iteration: 104000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000004, Time: 752.90
# New best model saved at iteration 105000 with test MSE: 0.0000004
# Iteration: 105000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 760.06
# Iteration: 106000, Train loss: 0.0000099, Test loss: 0.0000099, Best test loss: 0.0000004, Time: 767.18
# Iteration: 107000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000004, Time: 774.22
# New best model saved at iteration 108000 with test MSE: 0.0000004
# Iteration: 108000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 781.18
# Iteration: 109000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000004, Time: 788.04
# Iteration: 110000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000004, Time: 794.66
# New best model saved at iteration 111000 with test MSE: 0.0000003
# Iteration: 111000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000003, Time: 801.76
# Iteration: 112000, Train loss: 0.0000033, Test loss: 0.0000033, Best test loss: 0.0000003, Time: 808.85
# Iteration: 113000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000003, Time: 816.08
# Iteration: 114000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000003, Time: 823.08
# Iteration: 115000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000003, Time: 830.20
# New best model saved at iteration 116000 with test MSE: 0.0000003
# Iteration: 116000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000003, Time: 837.57
# Iteration: 117000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000003, Time: 844.85
# Iteration: 118000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000003, Time: 851.86
# New best model saved at iteration 119000 with test MSE: 0.0000002
# Iteration: 119000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 858.83
# Iteration: 120000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000002, Time: 865.53
# Iteration: 121000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 872.37
# Iteration: 122000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 879.63
# Iteration: 123000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 886.48
# New best model saved at iteration 124000 with test MSE: 0.0000002
# Iteration: 124000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 893.42
# Iteration: 125000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000002, Time: 900.97
# Iteration: 126000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 908.32
# Iteration: 127000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 915.65
# Iteration: 128000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000002, Time: 923.00
# Iteration: 129000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 930.28
# Iteration: 130000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 937.49
# Iteration: 131000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 944.97
# Iteration: 132000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 952.09
# Iteration: 133000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 959.19
# Iteration: 134000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000002, Time: 966.55
# Iteration: 135000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 973.80
# Iteration: 136000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 980.79
# Iteration: 137000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 988.04
# Iteration: 138000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000002, Time: 995.27
# Iteration: 139000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1002.54
# Iteration: 140000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1009.81
# Iteration: 141000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1017.10
# Iteration: 142000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1024.49
# Iteration: 143000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000002, Time: 1031.85
# Iteration: 144000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1039.07
# New best model saved at iteration 145000 with test MSE: 0.0000002
# Iteration: 145000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1046.45
# Iteration: 146000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000002, Time: 1053.35
# Iteration: 147000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000002, Time: 1060.47
# Iteration: 148000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000002, Time: 1067.71
# Iteration: 149000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000002, Time: 1074.73
# Iteration: 150000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1081.62
# Iteration: 151000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1088.73
# Iteration: 152000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1095.91
# Iteration: 153000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1102.99
# Iteration: 154000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 1110.24
# Iteration: 155000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 1117.47
# New best model saved at iteration 156000 with test MSE: 0.0000001
# Iteration: 156000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1124.71
# Iteration: 157000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1131.83
# Iteration: 158000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1139.08
# Iteration: 159000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1146.12
# Iteration: 160000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1153.65
# Iteration: 161000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000001, Time: 1161.12
# Iteration: 162000, Train loss: 0.0000055, Test loss: 0.0000055, Best test loss: 0.0000001, Time: 1168.07
# Iteration: 163000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1175.31
# Iteration: 164000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1182.54
# Iteration: 165000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 1189.44
# Iteration: 166000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1196.70
# New best model saved at iteration 167000 with test MSE: 0.0000001
# Iteration: 167000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1203.78
# Iteration: 168000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1210.47
# Iteration: 169000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1217.34
# Iteration: 170000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1224.69
# Iteration: 171000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 1231.75
# Iteration: 172000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1238.75
# Iteration: 173000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1245.97
# Iteration: 174000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1252.95
# Iteration: 175000, Train loss: 0.0000022, Test loss: 0.0000022, Best test loss: 0.0000001, Time: 1259.90
# Iteration: 176000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000001, Time: 1266.78
# Iteration: 177000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1273.53
# Iteration: 178000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1280.08
# Iteration: 179000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1286.49
# Iteration: 180000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1293.00
# Iteration: 181000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1299.75
# Iteration: 182000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000001, Time: 1306.85
# Iteration: 183000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000001, Time: 1313.63
# Iteration: 184000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000001, Time: 1320.58
# Iteration: 185000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1327.21
# Iteration: 186000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1333.80
# Iteration: 187000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000001, Time: 1340.54
# Iteration: 188000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1347.79
# New best model saved at iteration 189000 with test MSE: 0.0000001
# Iteration: 189000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 1355.07
# Iteration: 190000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000001, Time: 1362.36
# Iteration: 191000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1369.34
# Iteration: 192000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1376.85
# Iteration: 193000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1384.73
# Iteration: 194000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 1392.23
# Iteration: 195000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000001, Time: 1399.70
# Iteration: 196000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 1407.04
# Iteration: 197000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 1414.00
# Iteration: 198000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 1421.64
# Iteration: 199000, Train loss: 0.0000047, Test loss: 0.0000047, Best test loss: 0.0000001, Time: 1428.55
# Time (sec) to complete:
# 1461.7830984592438

# %%
# Load the best model parameters
best_params = load_model_params(resultdir, filename='model_params_best.pkl')

# Predictions
mse_list_x = []
mse_list_y = []

branch_inputs = inputs_test
trunk_inputs = grid
prediction_x, prediction_y = DeepONet(best_params, branch_inputs, trunk_inputs) # (bs, neval) = (1, nt*nz)

save_dict = {'Loading': inputs_test, 'pred_x': prediction_x, 'pred_y': prediction_y,\
             'target_x': outputs_x_test, 'target_y': outputs_y_test}

io.savemat(resultdir+'/deeponet_prediction.mat', save_dict)
print("Saved the prediction for all the test samples")
# Out:
# Loaded best model parameters
# Saved the prediction for all the test samples

# %%
sensor_loc = sensor_loc.T
def interpolate_solution(coordinates, prediction_field, target_field):
    """
    Interpolate scattered solution data onto a regular grid and plot the results.
    
    Args:
        coordinates: Array of shape (1314, 2) containing x,y coordinates of scattered points
        prediction_field: Predicted values at scattered points (1314,)
        target_field: Target values at scattered points (1314,)
        field_type: String indicating field type ("X" or "Y")
        length: Domain length in meters
        width: Domain width in meters
        save: Boolean to save the plot
        resultdir: Directory to save results
        sample_num: Sample number for saving
    """
    # Create fine regular grid for interpolation
    length = 2 # units
    width = 0.2 # units
    nx_fine, ny_fine = 201, 101  # Increased resolution
    x_fine = np.linspace(0, length, nx_fine)
    y_fine = np.linspace(0, width, ny_fine)
    X_fine, Y_fine = np.meshgrid(x_fine, y_fine)
    
    # Interpolate prediction and target fields onto regular grid
    prediction_interp = griddata(coordinates, prediction_field, 
                               (X_fine, Y_fine), method='cubic', fill_value=np.nan)
    target_interp = griddata(coordinates, target_field, 
                            (X_fine, Y_fine), method='cubic', fill_value=np.nan)
    
    error_interp = target_interp - prediction_interp
    
    return X_fine, Y_fine, prediction_interp, target_interp, error_interp

for i in range(inputs_test.shape[0]):
    branch_inputs = inputs_test[i].reshape(1, num_sensor)
    trunk_inputs = grid

    prediction_x_i, prediction_y_i = DeepONet(best_params, branch_inputs, trunk_inputs)
    target_x_i = outputs_x_test[i]
    target_y_i = outputs_y_test[i]

    mse_x_i = np.mean((prediction_x_i - target_x_i)**2)
    mse_list_x.append(mse_x_i.item())
    mse_y_i = np.mean((prediction_y_i - target_y_i)**2)
    mse_list_y.append(mse_y_i.item())

    if (i+1) % 10 == 0:
        print(colored('TEST SAMPLE '+str(i+1), 'red'))
        
        # Calculate metrics
        r2score_x = metrics.r2_score(target_x_i.flatten(), prediction_x_i.flatten())
        relerror_x = np.linalg.norm(target_x_i - prediction_x_i) / np.linalg.norm(target_x_i)
        r2score_x = float('%.4f'%r2score_x)
        relerror_x = float('%.4f'%relerror_x)
        r2score_y = metrics.r2_score(target_y_i.flatten(), prediction_y_i.flatten())
        relerror_y = np.linalg.norm(target_y_i - prediction_y_i) / np.linalg.norm(target_y_i)
        r2score_y = float('%.4f'%r2score_y)
        relerror_y = float('%.4f'%relerror_y)
        
        print('Rel. L2 Error (X-Displacement) = '+str(relerror_x)+', R2 score (X-Displacement) = '+str(r2score_x))
        print('Rel. L2 Error (Y-Displacement) = '+str(relerror_y)+', R2 score (Y-Displacement) = '+str(r2score_y))
        
        fig = plt.figure(figsize=(20, 5)) 
        plt.subplots_adjust(left=0.05, bottom=0.1, right=0.95, top=0.9, wspace=0.4, hspace=0.01)

        # Input Function Plot
        ax = fig.add_subplot(2, 4, (1,5))
        plt.plot(sensor_loc, inputs_test[i], color='blue', linewidth=2)
        plt.xlabel(r'$x$', fontsize=14, fontweight='bold', labelpad=10)  
        plt.ylabel(r'$Displacement$', fontsize=14, fontweight='bold', labelpad=10)
        plt.title('$Input\;Function$', fontsize=14, fontweight='bold', pad=15)  
        plt.grid(True)

        # Interpolated Displacement Fields
        X_fine, Y_fine, pred_x_interp, target_x_interp, error_x_interp = interpolate_solution(
            grid, prediction_x_i.flatten(), target_x_i.flatten())
        X_fine, Y_fine, pred_y_interp, target_y_interp, error_y_interp = interpolate_solution(
            grid, prediction_y_i.flatten(), target_y_i.flatten())

        # Scaling factors and interpolations
        scale_factor = 0.4
        target_displacement_resultant = (target_x_interp**2 + target_y_interp**2)**(0.5)
        predicted_displacement_resultant = (pred_x_interp**2 + pred_y_interp**2)**(0.5)
        X_fine_sc = X_fine + scale_factor * target_x_interp
        Y_fine_sc = Y_fine + scale_factor * target_y_interp

        # True X-Displacement
        ax = fig.add_subplot(2, 4, 2)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, target_x_interp, shading='auto', cmap='jet')
        ax.set_aspect('equal')
        ax.set_title('True X-Displacement', fontsize=14, fontweight='bold', pad=10)  # Title padding
        ax.set_ylabel('Width (m)', fontsize=12, labelpad=10)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.2)

        # Predicted X-Displacement
        ax = fig.add_subplot(2, 4, 3)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, pred_x_interp, shading='auto', cmap='jet')
        ax.set_aspect('equal')
        ax.set_title('Predicted X-Displacement', fontsize=14, fontweight='bold', pad=10)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.2)

        # X-Displacement Error with SymLogNorm
        ax = fig.add_subplot(2, 4, 4)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, error_x_interp, shading='auto', cmap='coolwarm', norm=SymLogNorm(linthresh=0.03))
        ax.set_aspect('equal')
        ax.set_title('X-Displacement Error', fontsize=14, fontweight='bold', pad=10)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.2)

        # True Y-Displacement
        ax = fig.add_subplot(2, 4, 6)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, target_y_interp, shading='auto', cmap='jet')
        ax.set_aspect('equal')
        ax.set_title('True Y-Displacement', fontsize=14, fontweight='bold', pad=10)
        ax.set_xlabel('Length (m)', fontsize=12, labelpad=3)
        ax.set_ylabel('Width (m)', fontsize=12, labelpad=10)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.28)

        # Predicted Y-Displacement
        ax = fig.add_subplot(2, 4, 7)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, pred_y_interp, shading='auto', cmap='jet')
        ax.set_aspect('equal')
        ax.set_title('Predicted Y-Displacement', fontsize=14, fontweight='bold', pad=10)
        ax.set_xlabel('Length (m)', fontsize=12, labelpad=3)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.28)

        # Y-Displacement Error with SymLogNorm
        ax = fig.add_subplot(2, 4, 8)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, error_y_interp, shading='auto', cmap='coolwarm', norm=SymLogNorm(linthresh=0.03))
        ax.set_aspect('equal')
        ax.set_title('Y-Displacement Error', fontsize=14, fontweight='bold', pad=10)
        ax.set_xlabel('Length (m)', fontsize=12, labelpad=3)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.28)
                
        if save == True:
            plt.savefig(os.path.join(resultdir,'Test_Sample_'+str(i+1)+'.pdf'))
            plt.show()
            plt.close()
        if save == False:
            plt.show()

        print(colored('#'*230, 'green'))

mse_ef = sum(mse_list_x) / len(mse_list_x)
print("Mean Squared Error Test (X-Displacement):\n", mse_ef)
mse_mech = sum(mse_list_y) / len(mse_list_y)
print("Mean Squared Error Test (Y-Displacement):\n", mse_mech)
# Out:
# TEST SAMPLE 10
# Rel. L2 Error (X-Displacement) = 0.0047, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0018, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 20
# Rel. L2 Error (X-Displacement) = 0.0052, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0029, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 30
# Rel. L2 Error (X-Displacement) = 0.0048, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0037, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 40
# Rel. L2 Error (X-Displacement) = 0.0051, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0039, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 50
# Rel. L2 Error (X-Displacement) = 0.0054, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0026, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 60
# Rel. L2 Error (X-Displacement) = 0.0102, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0024, R2 score (Y-Displacement) = 0.9999
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 70
# Rel. L2 Error (X-Displacement) = 0.0067, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0032, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 80
# Rel. L2 Error (X-Displacement) = 0.0048, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0023, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 90
# Rel. L2 Error (X-Displacement) = 0.0048, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0027, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 100
# Rel. L2 Error (X-Displacement) = 0.0059, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0028, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 110
# Rel. L2 Error (X-Displacement) = 0.0036, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0031, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 120
# Rel. L2 Error (X-Displacement) = 0.0091, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0045, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 130
# Rel. L2 Error (X-Displacement) = 0.0057, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0022, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 140
# Rel. L2 Error (X-Displacement) = 0.0041, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0026, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 150
# Rel. L2 Error (X-Displacement) = 0.0106, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0038, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 160
# Rel. L2 Error (X-Displacement) = 0.0049, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0031, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 170
# Rel. L2 Error (X-Displacement) = 0.0077, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0029, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 180
# Rel. L2 Error (X-Displacement) = 0.0038, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0028, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 190
# Rel. L2 Error (X-Displacement) = 0.0055, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0034, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 200
# Rel. L2 Error (X-Displacement) = 0.0043, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0031, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# Mean Squared Error Test (X-Displacement):
#  4.613826930288667e-08
# Mean Squared Error Test (Y-Displacement):
#  2.9578710442734745e-07
