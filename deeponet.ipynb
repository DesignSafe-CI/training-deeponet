# %% [markdown]
# ### The script solves the linear elasticity equation on the cantilever beam under dsiaplecement boundary conditions. Governing equation: $-\nabla\cdot \sigma = 0$.
#
# ![alt text](schematic.png)

# %%
import jax.numpy as jnp
import numpy.random as npr
from jax import jit, grad, vmap
from jax.example_libraries.optimizers import adam
from jax import value_and_grad
from functools import partial
from jax import jacfwd, jacrev
import jax.nn as jnn
import math
from jax import random
import jax
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn import metrics
from flax import linen as nn
import sklearn.metrics
from scipy.interpolate import griddata
from matplotlib.colors import SymLogNorm

import os
import time
from termcolor import colored
from scipy.io import loadmat
import scipy.io as io
import pickle

import sys
sys.path.append("../..")

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 9})
import seaborn as sns
sns.set_style("white")
sns.set_style("ticks")

import warnings
warnings.filterwarnings("ignore")

# Check where gpu is enable or not
from jax.lib import xla_bridge
print(xla_bridge.get_backend().platform)
# Out:
# cpu

# %%
save = True
if save == True:
    resultdir = os.path.join(os.getcwd(), 'deeponet_results')
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

# %%
# Load the data
data = loadmat('./cantilever_beam_deflection.mat') # Load the .mat file
print("Shape of loading matrix (Input Function):", data['loading'].shape) # Input to deeponet - varying loading conditions
print("Shape of Displacement-X matrix (Output Function):", data['disp_x'].shape) # Output from deeponet - The corresponding deflection in X-direction
print("Shape of Displacement-Y matrix (Output Function):", data['disp_y'].shape) # Output from deeponet - The corresponding deflection in Y-direction

# Convert NumPy arrays to tensors
inputs = jnp.array(data['loading'])
sensor_loc = jnp.array(data['sensor_loc_loading'])
outputs_x = jnp.array(data['disp_x'])
outputs_y = jnp.array(data['disp_y'])
grid_x = data['coord_x'].T
grid_y = data['coord_y'].T
grid = jnp.concatenate([grid_x, grid_y], axis=1, dtype=None)
print("Shape of grid for the cantilever beam:", grid.shape) # (n,2)

num_train = 800
num_test = 200
# Split the data into training (800) and testing (200) samples
inputs_train, inputs_test, outputs_x_train, outputs_x_test, outputs_y_train, outputs_y_test = train_test_split(inputs, outputs_x, outputs_y, test_size=200, random_state=0)
print("Shape of loading matrix used for training:", inputs_train.shape)
print("Shape of x-displacement matrix corresponding to the training loads:", outputs_x_train.shape)
print("Shape of y-displacement matrix corresponding to the training loads:", outputs_y_train.shape)
print("Shape of loading matrix used for testing:", inputs_test.shape)
print("Shape of x-displacement matrix corresponding to the testing loads:", outputs_x_test.shape)
print("Shape of y-displacement matrix corresponding to the testing loads:", outputs_y_test.shape)
print('#'*100)
# Out:
# Shape of loading matrix (Input Function): (1000, 100)
# Shape of Displacement-X matrix (Output Function): (1000, 1314)
# Shape of Displacement-Y matrix (Output Function): (1000, 1314)
# Shape of grid for the cantilever beam: (1314, 2)
# Shape of loading matrix used for training: (800, 100)
# Shape of x-displacement matrix corresponding to the training loads: (800, 1314)
# Shape of y-displacement matrix corresponding to the training loads: (800, 1314)
# Shape of loading matrix used for testing: (200, 100)
# Shape of x-displacement matrix corresponding to the testing loads: (200, 1314)
# Shape of y-displacement matrix corresponding to the testing loads: (200, 1314)
# ####################################################################################################

# %%
# network parameters.
p = 100 # Number of output neurons in both the branch and trunk net.
num_sensor = inputs_train.shape[1]
input_neurons_branch = num_sensor
input_neurons_trunk = grid.shape[1]
layer_sizes_b = [input_neurons_branch] + [100]*6 + [2*p]
layer_sizes_t = [input_neurons_trunk] + [100]*6 + [2*p]

bs = 450 # batch size
n_epochs = 200000

# %%
# Initialize the Glorot (Xavier) normal distribution for weight initialization
initializer = jax.nn.initializers.glorot_normal()

def init_glorot_params(layer_sizes, key = random.PRNGKey(0)):
    """
    Initialize the parameters of the neural network using Glorot (Xavier) initialization.

    Args:
    layer_sizes (list): List of integers representing the size of each layer.
    key (PRNGKey): Random number generator key for reproducibility.

    Returns:
    list: List of tuples, each containing weights and biases for a layer.
    """
    return [(initializer(key, (m, n), jnp.float32), jnp.zeros(n))
            for m, n, in zip(layer_sizes[:-1], layer_sizes[1:])]

params_branch = init_glorot_params(layer_sizes=layer_sizes_b)
params_trunk = init_glorot_params(layer_sizes=layer_sizes_t)
params= (params_branch, params_trunk)

# Initialize the Adam optimizer
opt_init, opt_update, get_params = adam(step_size=1e-3, b1=0.9, b2=0.999, eps=1e-08)
opt_state = opt_init(params)

# %%
def BranchNet(params, x):
    """
    Implement the branch network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (array): Input to the branch network.

    Returns:
    array: Output of the branch network.
    """
    def single_forward(params, x):
        for w, b in params:
            outputs = jnp.dot(x, w) + b
            x = jnn.silu(outputs)
        return outputs

    return vmap(partial(single_forward, params))(x)

def TrunkNet(params, x, y):
    """
    Implement the trunk network of the DeepONet.

    Args:
    params (list): List of weight and bias tuples for each layer.
    x (float): First input to the trunk network.
    t (float): Second input to the trunk network.

    Returns:
    array: Output of the trunk network.
    """
    inputs = jnp.array([x, y])
    for w, b in params:
        outputs = jnp.dot(inputs, w) + b
        inputs = jnn.silu(outputs)
    return outputs

@jit
def DeepONet(params, branch_inputs, trunk_inputs):
    """
    Implement the complete DeepONet architecture.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.

    Returns:
    array: Output of the DeepONet.
    """
    params_branch, params_trunk = params
    branch_outputs = lambda x: BranchNet(params_branch, x)
    b_out = branch_outputs(branch_inputs)
    trunk_output = lambda x, y: TrunkNet(params_trunk, x, y)
    t_out = vmap(trunk_output)(trunk_inputs[:,0],trunk_inputs[:,1])
    results_x = jnp.einsum('ik, lk -> il',b_out[:,0:p], t_out[:,0:p])
    results_y = jnp.einsum('ik, lk -> il',b_out[:,p:2*p], t_out[:,p:2*p])
    return results_x, results_y

# %%
def objective(params, branch_inputs, trunk_inputs, target_values_x, target_values_y):
    """
    Define the objective function (loss function) for training.

    Args:
    params (tuple): Tuple containing branch and trunk network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values to compare against.

    Returns:
    float: Mean squared error loss.
    """

    predictions_x, predictions_y = DeepONet(params, branch_inputs, trunk_inputs)
    loss_mse = jnp.mean((predictions_x - target_values_x)**2) + jnp.mean((predictions_y - target_values_y)**2)
    return loss_mse


# Adam optimizer
@jit
def network_update(params, branch_inputs, trunk_inputs, target_values_x, target_values_y, opt_state):
    """
    Compute the gradient for a batch and update the parameters.

    Args:
    params (tuple): Current network parameters.
    branch_inputs (array): Inputs for the branch network.
    trunk_inputs (array): Inputs for the trunk network.
    target_values (array): True output values.
    opt_state: Current state of the optimizer.

    Returns:
    tuple: Updated parameters, updated optimizer state, and current loss value.
    """
    value, grads = value_and_grad(objective)(params, branch_inputs, trunk_inputs, target_values_x, target_values_y)
    opt_state = opt_update(0, grads, opt_state)
    return get_params(opt_state), opt_state, value

# %%
def save_model_params(params, resultdir, filename='model_params.pkl'):
    if not os.path.exists(resultdir):
        os.makedirs(resultdir)

    save_path = os.path.join(resultdir, filename)
    with open(save_path, 'wb') as f:
        pickle.dump(params, f)

def load_model_params(resultdir, filename='model_params.pkl'):
    load_path = os.path.join(resultdir, filename)
    with open(load_path, 'rb') as f:
        params = pickle.load(f)
    return params

# Saving
if save:
    save_model_params(params, resultdir)

# Loading (uncomment when needed)
# model_params = load_model_params(resultdir)

# %%
num_samples = len(inputs_train)
## Training of DeepONet
start = time.time() # start time of training
best_test_mse = float('inf')  # Initialize with infinity

print ("------------- START TRAINING -------------")
# Save initial model at 0th iteration
save_model_params(params, resultdir, filename='model_params_best.pkl')
print("Saved initial model at iteration 0")

iteration_list, loss_list, test_loss_list = [], [], []
iteration = 0

for iteration in range(n_epochs):
    indices = jax.random.permutation(jax.random.PRNGKey(0), num_samples)
    batch_index = indices[0:bs]
    inputs_train_shuffled = inputs_train[batch_index]
    outputs_x_train_shuffled = outputs_x_train[batch_index]
    outputs_y_train_shuffled = outputs_y_train[batch_index]
    target_values_x = outputs_x_train_shuffled
    target_values_y = outputs_y_train_shuffled
    branch_inputs = inputs_train_shuffled
    trunk_inputs = grid

    params, opt_state, value = network_update(params, branch_inputs, trunk_inputs, target_values_x, target_values_y, opt_state)

    if iteration % 1000 == 0:
        
        predictions_x, predictions_y = DeepONet(params, branch_inputs, trunk_inputs)
        test_mse = jnp.mean((predictions_x - target_values_x)**2) + jnp.mean((predictions_y - target_values_y)**2)

        # Compare current test error with the best so far
        if test_mse < best_test_mse:
            best_test_mse = test_mse
            # Save the model as it's the best so far
            save_model_params(params, resultdir, filename='model_params_best.pkl')
            print(f"New best model saved at iteration {iteration} with test MSE: {test_mse:.7f}")

        finish = time.time() - start
        print(f"Iteration: {iteration:3d}, Train loss: {objective(params, branch_inputs, trunk_inputs, target_values_x, target_values_y):.7f}, Test loss: {test_mse:.7f}, Best test loss: {best_test_mse:.7f}, Time: {finish:.2f}")

    iteration_list.append(iteration)
    loss_list.append(objective(params, branch_inputs, trunk_inputs, target_values_x, target_values_y))
    test_loss_list.append(test_mse)

if save:
    np.save(os.path.join(resultdir, 'iteration_list.npy'), np.asarray(iteration_list))
    np.save(os.path.join(resultdir, 'loss_list.npy'), np.asarray(loss_list))
    np.save(os.path.join(resultdir, 'test_loss_list.npy'), np.asarray(test_loss_list))

# Plotting code remains the same
plt.figure()
plt.plot(iteration_list, loss_list, 'g', label='Training loss')
plt.plot(iteration_list, test_loss_list, '-b', label='Test loss')
plt.yscale("log")
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

if save:
    plt.savefig(os.path.join(resultdir, 'loss_plot.pdf'))

# end timer
finish = time.time() - start
print("Time (sec) to complete:\n" + str(finish))
# Out:
# ------------- START TRAINING -------------
# Saved initial model at iteration 0
# New best model saved at iteration 0 with test MSE: 0.0390862
# Iteration:   0, Train loss: 0.0390862, Test loss: 0.0390862, Best test loss: 0.0390862, Time: 0.75
# New best model saved at iteration 1000 with test MSE: 0.0027267
# Iteration: 1000, Train loss: 0.0027267, Test loss: 0.0027267, Best test loss: 0.0027267, Time: 16.15
# New best model saved at iteration 2000 with test MSE: 0.0007219
# Iteration: 2000, Train loss: 0.0007219, Test loss: 0.0007219, Best test loss: 0.0007219, Time: 31.29
# New best model saved at iteration 3000 with test MSE: 0.0003320
# Iteration: 3000, Train loss: 0.0003320, Test loss: 0.0003320, Best test loss: 0.0003320, Time: 46.27
# New best model saved at iteration 4000 with test MSE: 0.0002126
# Iteration: 4000, Train loss: 0.0002126, Test loss: 0.0002126, Best test loss: 0.0002126, Time: 61.32
# New best model saved at iteration 5000 with test MSE: 0.0001756
# Iteration: 5000, Train loss: 0.0001756, Test loss: 0.0001756, Best test loss: 0.0001756, Time: 76.26
# New best model saved at iteration 6000 with test MSE: 0.0000898
# Iteration: 6000, Train loss: 0.0000898, Test loss: 0.0000898, Best test loss: 0.0000898, Time: 91.23
# New best model saved at iteration 7000 with test MSE: 0.0000824
# Iteration: 7000, Train loss: 0.0000824, Test loss: 0.0000824, Best test loss: 0.0000824, Time: 106.09
# New best model saved at iteration 8000 with test MSE: 0.0000789
# Iteration: 8000, Train loss: 0.0000789, Test loss: 0.0000789, Best test loss: 0.0000789, Time: 121.07
# New best model saved at iteration 9000 with test MSE: 0.0000648
# Iteration: 9000, Train loss: 0.0000648, Test loss: 0.0000648, Best test loss: 0.0000648, Time: 136.07
# New best model saved at iteration 10000 with test MSE: 0.0000547
# Iteration: 10000, Train loss: 0.0000547, Test loss: 0.0000547, Best test loss: 0.0000547, Time: 151.02
# New best model saved at iteration 11000 with test MSE: 0.0000380
# Iteration: 11000, Train loss: 0.0000380, Test loss: 0.0000380, Best test loss: 0.0000380, Time: 165.98
# New best model saved at iteration 12000 with test MSE: 0.0000294
# Iteration: 12000, Train loss: 0.0000294, Test loss: 0.0000294, Best test loss: 0.0000294, Time: 181.07
# New best model saved at iteration 13000 with test MSE: 0.0000254
# Iteration: 13000, Train loss: 0.0000254, Test loss: 0.0000254, Best test loss: 0.0000254, Time: 196.13
# New best model saved at iteration 14000 with test MSE: 0.0000235
# Iteration: 14000, Train loss: 0.0000235, Test loss: 0.0000235, Best test loss: 0.0000235, Time: 211.16
# New best model saved at iteration 15000 with test MSE: 0.0000187
# Iteration: 15000, Train loss: 0.0000187, Test loss: 0.0000187, Best test loss: 0.0000187, Time: 226.22
# New best model saved at iteration 16000 with test MSE: 0.0000180
# Iteration: 16000, Train loss: 0.0000180, Test loss: 0.0000180, Best test loss: 0.0000180, Time: 241.15
# Iteration: 17000, Train loss: 0.0000199, Test loss: 0.0000199, Best test loss: 0.0000180, Time: 256.14
# New best model saved at iteration 18000 with test MSE: 0.0000160
# Iteration: 18000, Train loss: 0.0000160, Test loss: 0.0000160, Best test loss: 0.0000160, Time: 271.03
# New best model saved at iteration 19000 with test MSE: 0.0000101
# Iteration: 19000, Train loss: 0.0000101, Test loss: 0.0000101, Best test loss: 0.0000101, Time: 285.94
# New best model saved at iteration 20000 with test MSE: 0.0000090
# Iteration: 20000, Train loss: 0.0000090, Test loss: 0.0000090, Best test loss: 0.0000090, Time: 300.97
# Iteration: 21000, Train loss: 0.0000146, Test loss: 0.0000146, Best test loss: 0.0000090, Time: 316.05
# New best model saved at iteration 22000 with test MSE: 0.0000086
# Iteration: 22000, Train loss: 0.0000086, Test loss: 0.0000086, Best test loss: 0.0000086, Time: 331.07
# New best model saved at iteration 23000 with test MSE: 0.0000071
# Iteration: 23000, Train loss: 0.0000071, Test loss: 0.0000071, Best test loss: 0.0000071, Time: 346.04
# New best model saved at iteration 24000 with test MSE: 0.0000050
# Iteration: 24000, Train loss: 0.0000050, Test loss: 0.0000050, Best test loss: 0.0000050, Time: 361.02
# Iteration: 25000, Train loss: 0.0000156, Test loss: 0.0000156, Best test loss: 0.0000050, Time: 376.11
# New best model saved at iteration 26000 with test MSE: 0.0000033
# Iteration: 26000, Train loss: 0.0000033, Test loss: 0.0000033, Best test loss: 0.0000033, Time: 390.94
# Iteration: 27000, Train loss: 0.0000033, Test loss: 0.0000033, Best test loss: 0.0000033, Time: 405.64
# Iteration: 28000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000033, Time: 420.32
# Iteration: 29000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000033, Time: 435.05
# New best model saved at iteration 30000 with test MSE: 0.0000025
# Iteration: 30000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000025, Time: 450.04
# Iteration: 31000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000025, Time: 465.04
# Iteration: 32000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000025, Time: 480.08
# Iteration: 33000, Train loss: 0.0000037, Test loss: 0.0000037, Best test loss: 0.0000025, Time: 495.28
# Iteration: 34000, Train loss: 0.0000053, Test loss: 0.0000053, Best test loss: 0.0000025, Time: 509.98
# Iteration: 35000, Train loss: 0.0000077, Test loss: 0.0000077, Best test loss: 0.0000025, Time: 524.81
# Iteration: 36000, Train loss: 0.0000060, Test loss: 0.0000060, Best test loss: 0.0000025, Time: 539.68
# Iteration: 37000, Train loss: 0.0000035, Test loss: 0.0000035, Best test loss: 0.0000025, Time: 554.77
# New best model saved at iteration 38000 with test MSE: 0.0000020
# Iteration: 38000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000020, Time: 569.77
# Iteration: 39000, Train loss: 0.0000091, Test loss: 0.0000091, Best test loss: 0.0000020, Time: 584.89
# Iteration: 40000, Train loss: 0.0000053, Test loss: 0.0000053, Best test loss: 0.0000020, Time: 600.18
# Iteration: 41000, Train loss: 0.0000068, Test loss: 0.0000068, Best test loss: 0.0000020, Time: 615.74
# Iteration: 42000, Train loss: 0.0000040, Test loss: 0.0000040, Best test loss: 0.0000020, Time: 631.56
# Iteration: 43000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000020, Time: 647.32
# New best model saved at iteration 44000 with test MSE: 0.0000015
# Iteration: 44000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000015, Time: 663.20
# Iteration: 45000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000015, Time: 678.86
# Iteration: 46000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000015, Time: 694.27
# Iteration: 47000, Train loss: 0.0000064, Test loss: 0.0000064, Best test loss: 0.0000015, Time: 709.98
# Iteration: 48000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000015, Time: 725.11
# New best model saved at iteration 49000 with test MSE: 0.0000011
# Iteration: 49000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000011, Time: 740.19
# New best model saved at iteration 50000 with test MSE: 0.0000008
# Iteration: 50000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000008, Time: 755.27
# Iteration: 51000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000008, Time: 770.42
# Iteration: 52000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000008, Time: 785.53
# Iteration: 53000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000008, Time: 800.65
# Iteration: 54000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000008, Time: 815.93
# New best model saved at iteration 55000 with test MSE: 0.0000007
# Iteration: 55000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 830.97
# Iteration: 56000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 845.90
# Iteration: 57000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000007, Time: 860.79
# Iteration: 58000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 875.40
# Iteration: 59000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 890.27
# Iteration: 60000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000007, Time: 905.07
# Iteration: 61000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 920.10
# Iteration: 62000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 935.19
# Iteration: 63000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 950.06
# Iteration: 64000, Train loss: 0.0000034, Test loss: 0.0000034, Best test loss: 0.0000007, Time: 965.03
# Iteration: 65000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000007, Time: 979.87
# Iteration: 66000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000007, Time: 995.00
# Iteration: 67000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000007, Time: 1010.05
# Iteration: 68000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000007, Time: 1025.18
# Iteration: 69000, Train loss: 0.0000030, Test loss: 0.0000030, Best test loss: 0.0000007, Time: 1040.34
# Iteration: 70000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000007, Time: 1055.43
# Iteration: 71000, Train loss: 0.0000052, Test loss: 0.0000052, Best test loss: 0.0000007, Time: 1070.26
# New best model saved at iteration 72000 with test MSE: 0.0000005
# Iteration: 72000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 1085.39
# Iteration: 73000, Train loss: 0.0000025, Test loss: 0.0000025, Best test loss: 0.0000005, Time: 1100.51
# Iteration: 74000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 1115.72
# Iteration: 75000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000005, Time: 1130.88
# Iteration: 76000, Train loss: 0.0000043, Test loss: 0.0000043, Best test loss: 0.0000005, Time: 1146.01
# New best model saved at iteration 77000 with test MSE: 0.0000005
# Iteration: 77000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 1161.19
# Iteration: 78000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000005, Time: 1176.40
# Iteration: 79000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000005, Time: 1191.48
# Iteration: 80000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000005, Time: 1206.57
# Iteration: 81000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000005, Time: 1221.63
# Iteration: 82000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000005, Time: 1236.51
# Iteration: 83000, Train loss: 0.0000048, Test loss: 0.0000048, Best test loss: 0.0000005, Time: 1250.98
# Iteration: 84000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000005, Time: 2208.33
# Iteration: 85000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000005, Time: 2223.15
# Iteration: 86000, Train loss: 0.0000018, Test loss: 0.0000018, Best test loss: 0.0000005, Time: 2237.61
# Iteration: 87000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000005, Time: 2252.01
# Iteration: 88000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 2266.37
# Iteration: 89000, Train loss: 0.0000026, Test loss: 0.0000026, Best test loss: 0.0000005, Time: 2280.83
# Iteration: 90000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000005, Time: 2295.08
# Iteration: 91000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000005, Time: 2309.25
# Iteration: 92000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000005, Time: 3294.03
# Iteration: 93000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000005, Time: 3308.65
# Iteration: 94000, Train loss: 0.0000015, Test loss: 0.0000015, Best test loss: 0.0000005, Time: 3323.21
# Iteration: 95000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000005, Time: 3338.10
# Iteration: 96000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000005, Time: 3353.10
# Iteration: 97000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3367.91
# Iteration: 98000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3382.72
# Iteration: 99000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000005, Time: 3397.49
# Iteration: 100000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000005, Time: 3412.26
# Iteration: 101000, Train loss: 0.0000020, Test loss: 0.0000020, Best test loss: 0.0000005, Time: 3427.09
# Iteration: 102000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000005, Time: 3442.05
# New best model saved at iteration 103000 with test MSE: 0.0000004
# Iteration: 103000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000004, Time: 3456.85
# Iteration: 104000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000004, Time: 4397.97
# Iteration: 105000, Train loss: 0.0000027, Test loss: 0.0000027, Best test loss: 0.0000004, Time: 4412.78
# Iteration: 106000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000004, Time: 4427.74
# Iteration: 107000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000004, Time: 4442.59
# Iteration: 108000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 4457.49
# Iteration: 109000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000004, Time: 5437.45
# Iteration: 110000, Train loss: 0.0000029, Test loss: 0.0000029, Best test loss: 0.0000004, Time: 5452.47
# Iteration: 111000, Train loss: 0.0000014, Test loss: 0.0000014, Best test loss: 0.0000004, Time: 5467.20
# New best model saved at iteration 112000 with test MSE: 0.0000003
# Iteration: 112000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000003, Time: 5481.92
# Iteration: 113000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000003, Time: 5496.58
# Iteration: 114000, Train loss: 0.0000008, Test loss: 0.0000008, Best test loss: 0.0000003, Time: 5511.22
# Iteration: 115000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000003, Time: 5525.83
# Iteration: 116000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000003, Time: 5540.82
# Iteration: 117000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000003, Time: 5555.77
# Iteration: 118000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000003, Time: 5570.73
# New best model saved at iteration 119000 with test MSE: 0.0000002
# Iteration: 119000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 5585.76
# Iteration: 120000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 5600.70
# Iteration: 121000, Train loss: 0.0000024, Test loss: 0.0000024, Best test loss: 0.0000002, Time: 6521.97
# New best model saved at iteration 122000 with test MSE: 0.0000002
# Iteration: 122000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 6536.86
# Iteration: 123000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 6551.75
# Iteration: 124000, Train loss: 0.0000013, Test loss: 0.0000013, Best test loss: 0.0000002, Time: 7502.82
# Iteration: 125000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000002, Time: 7517.55
# Iteration: 126000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 7532.44
# Iteration: 127000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 7547.30
# New best model saved at iteration 128000 with test MSE: 0.0000002
# Iteration: 128000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 7562.23
# Iteration: 129000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000002, Time: 7577.19
# Iteration: 130000, Train loss: 0.0000016, Test loss: 0.0000016, Best test loss: 0.0000002, Time: 7592.21
# Iteration: 131000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000002, Time: 7607.27
# Iteration: 132000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000002, Time: 7622.17
# Iteration: 133000, Train loss: 0.0000039, Test loss: 0.0000039, Best test loss: 0.0000002, Time: 7637.19
# Iteration: 134000, Train loss: 0.0000019, Test loss: 0.0000019, Best test loss: 0.0000002, Time: 7652.25
# Iteration: 135000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000002, Time: 7667.24
# Iteration: 136000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000002, Time: 7682.22
# New best model saved at iteration 137000 with test MSE: 0.0000001
# Iteration: 137000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 8613.46
# Iteration: 138000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 8628.46
# Iteration: 139000, Train loss: 0.0000053, Test loss: 0.0000053, Best test loss: 0.0000001, Time: 8643.39
# Iteration: 140000, Train loss: 0.0000009, Test loss: 0.0000009, Best test loss: 0.0000001, Time: 9652.57
# Iteration: 141000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 9667.32
# Iteration: 142000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 9682.19
# New best model saved at iteration 143000 with test MSE: 0.0000001
# Iteration: 143000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 9697.15
# Iteration: 144000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 9711.97
# Iteration: 145000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 9726.91
# Iteration: 146000, Train loss: 0.0000017, Test loss: 0.0000017, Best test loss: 0.0000001, Time: 9741.85
# Iteration: 147000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 9756.73
# Iteration: 148000, Train loss: 0.0000116, Test loss: 0.0000116, Best test loss: 0.0000001, Time: 9771.50
# Iteration: 149000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000001, Time: 9786.35
# Iteration: 150000, Train loss: 0.0000010, Test loss: 0.0000010, Best test loss: 0.0000001, Time: 9801.20
# Iteration: 151000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 9816.05
# Iteration: 152000, Train loss: 0.0000055, Test loss: 0.0000055, Best test loss: 0.0000001, Time: 10796.14
# Iteration: 153000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 10810.81
# Iteration: 154000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 10825.66
# Iteration: 155000, Train loss: 0.0000089, Test loss: 0.0000089, Best test loss: 0.0000001, Time: 11837.00
# Iteration: 156000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 11851.85
# Iteration: 157000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 11866.51
# Iteration: 158000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 11880.81
# Iteration: 159000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 11894.95
# Iteration: 160000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 11909.51
# Iteration: 161000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 11923.88
# Iteration: 162000, Train loss: 0.0000012, Test loss: 0.0000012, Best test loss: 0.0000001, Time: 11938.10
# Iteration: 163000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 11952.50
# Iteration: 164000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 11966.84
# Iteration: 165000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 11981.20
# Iteration: 166000, Train loss: 0.0000028, Test loss: 0.0000028, Best test loss: 0.0000001, Time: 11995.64
# Iteration: 167000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 12010.02
# Iteration: 168000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 12024.34
# New best model saved at iteration 169000 with test MSE: 0.0000001
# Iteration: 169000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 12038.73
# Iteration: 170000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 12053.18
# Iteration: 171000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 12067.36
# Iteration: 172000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 12081.82
# Iteration: 173000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 12096.35
# New best model saved at iteration 174000 with test MSE: 0.0000001
# Iteration: 174000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 13082.85
# Iteration: 175000, Train loss: 0.0000007, Test loss: 0.0000007, Best test loss: 0.0000001, Time: 13097.57
# Iteration: 176000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 13112.16
# Iteration: 177000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 13126.89
# Iteration: 178000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 14065.82
# Iteration: 179000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 14080.27
# New best model saved at iteration 180000 with test MSE: 0.0000001
# Iteration: 180000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 14094.88
# Iteration: 181000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 14109.49
# Iteration: 182000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 14124.18
# Iteration: 183000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 14138.90
# Iteration: 184000, Train loss: 0.0000006, Test loss: 0.0000006, Best test loss: 0.0000001, Time: 14153.71
# Iteration: 185000, Train loss: 0.0000023, Test loss: 0.0000023, Best test loss: 0.0000001, Time: 14168.34
# Iteration: 186000, Train loss: 0.0000011, Test loss: 0.0000011, Best test loss: 0.0000001, Time: 14183.08
# Iteration: 187000, Train loss: 0.0000005, Test loss: 0.0000005, Best test loss: 0.0000001, Time: 14197.87
# Iteration: 188000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 14212.49
# New best model saved at iteration 189000 with test MSE: 0.0000001
# Iteration: 189000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 14227.18
# Iteration: 190000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 15284.24
# Iteration: 191000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 15298.91
# Iteration: 192000, Train loss: 0.0000003, Test loss: 0.0000003, Best test loss: 0.0000001, Time: 15313.46
# Iteration: 193000, Train loss: 0.0000021, Test loss: 0.0000021, Best test loss: 0.0000001, Time: 15328.22
# Iteration: 194000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 15343.05
# Iteration: 195000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 16371.32
# Iteration: 196000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 16385.96
# Iteration: 197000, Train loss: 0.0000004, Test loss: 0.0000004, Best test loss: 0.0000001, Time: 16400.70
# New best model saved at iteration 198000 with test MSE: 0.0000001
# Iteration: 198000, Train loss: 0.0000001, Test loss: 0.0000001, Best test loss: 0.0000001, Time: 16415.37
# Iteration: 199000, Train loss: 0.0000002, Test loss: 0.0000002, Best test loss: 0.0000001, Time: 16430.04
# Time (sec) to complete:
# 16446.993324041367

# %%
# Load the best model parameters
best_params = load_model_params(resultdir, filename='model_params_best.pkl')
print("Loaded best model parameters")

# Predictions
mse_list_x = []
mse_list_y = []

branch_inputs = inputs_test
trunk_inputs_ef = grid
prediction_x, prediction_y = DeepONet(params, branch_inputs, trunk_inputs) # (bs, neval) = (1, nt*nz)

save_dict = {'Loading': inputs_test, 'pred_x': prediction_x, 'pred_y': prediction_y,\
             'target_x': outputs_x_test, 'target_y': outputs_y_test}

io.savemat(resultdir+'/deeponet_prediction.mat', save_dict)
print("Saved the prediction for all the test samples")
# Out:
# Loaded best model parameters
# Saved the prediction for all the test samples

# %%
sensor_loc = sensor_loc.T
def interpolate_solution(coordinates, prediction_field, target_field):
    """
    Interpolate scattered solution data onto a regular grid and plot the results.
    
    Args:
        coordinates: Array of shape (1314, 2) containing x,y coordinates of scattered points
        prediction_field: Predicted values at scattered points (1314,)
        target_field: Target values at scattered points (1314,)
        field_type: String indicating field type ("X" or "Y")
        length: Domain length in meters
        width: Domain width in meters
        save: Boolean to save the plot
        resultdir: Directory to save results
        sample_num: Sample number for saving
    """
    # Create fine regular grid for interpolation
    length = 2 # units
    width = 0.2 # units
    nx_fine, ny_fine = 201, 101  # Increased resolution
    x_fine = np.linspace(0, length, nx_fine)
    y_fine = np.linspace(0, width, ny_fine)
    X_fine, Y_fine = np.meshgrid(x_fine, y_fine)
    
    # Interpolate prediction and target fields onto regular grid
    prediction_interp = griddata(coordinates, prediction_field, 
                               (X_fine, Y_fine), method='cubic', fill_value=np.nan)
    target_interp = griddata(coordinates, target_field, 
                            (X_fine, Y_fine), method='cubic', fill_value=np.nan)
    
    error_interp = target_interp - prediction_interp
    
    return X_fine, Y_fine, prediction_interp, target_interp, error_interp

for i in range(inputs_test.shape[0]):
    branch_inputs = inputs_test[i].reshape(1, num_sensor)
    trunk_inputs = grid

    prediction_x_i, prediction_y_i = DeepONet(params, branch_inputs, trunk_inputs)
    target_x_i = outputs_x_test[i]
    target_y_i = outputs_y_test[i]

    mse_x_i = np.mean((prediction_x_i - target_x_i)**2)
    mse_list_x.append(mse_x_i.item())
    mse_y_i = np.mean((prediction_y_i - target_y_i)**2)
    mse_list_y.append(mse_y_i.item())

    if (i+1) % 10 == 0:
        print(colored('TEST SAMPLE '+str(i+1), 'red'))
        
        # Calculate metrics
        r2score_x = metrics.r2_score(target_x_i.flatten(), prediction_x_i.flatten())
        relerror_x = np.linalg.norm(target_x_i - prediction_x_i) / np.linalg.norm(target_x_i)
        r2score_x = float('%.4f'%r2score_x)
        relerror_x = float('%.4f'%relerror_x)
        r2score_y = metrics.r2_score(target_y_i.flatten(), prediction_y_i.flatten())
        relerror_y = np.linalg.norm(target_y_i - prediction_y_i) / np.linalg.norm(target_y_i)
        r2score_y = float('%.4f'%r2score_y)
        relerror_y = float('%.4f'%relerror_y)
        
        print('Rel. L2 Error (X-Displacement) = '+str(relerror_x)+', R2 score (X-Displacement) = '+str(r2score_x))
        print('Rel. L2 Error (Y-Displacement) = '+str(relerror_y)+', R2 score (Y-Displacement) = '+str(r2score_y))
        
        fig = plt.figure(figsize=(20, 5)) 
        plt.subplots_adjust(left=0.05, bottom=0.1, right=0.95, top=0.9, wspace=0.4, hspace=0.01)

        # Input Function Plot
        ax = fig.add_subplot(2, 4, (1,5))
        plt.plot(sensor_loc, inputs_test[i], color='blue', linewidth=2)
        plt.xlabel(r'$x$', fontsize=14, fontweight='bold', labelpad=10)  
        plt.ylabel(r'$Load$', fontsize=14, fontweight='bold', labelpad=10)
        plt.title('$Input\;Function$', fontsize=14, fontweight='bold', pad=15)  
        plt.grid(True)

        # Interpolated Displacement Fields
        X_fine, Y_fine, pred_x_interp, target_x_interp, error_x_interp = interpolate_solution(
            grid, prediction_x_i.flatten(), target_x_i.flatten())
        X_fine, Y_fine, pred_y_interp, target_y_interp, error_y_interp = interpolate_solution(
            grid, prediction_y_i.flatten(), target_y_i.flatten())

        # Scaling factors and interpolations
        scale_factor = 0.4
        target_displacement_resultant = (target_x_interp**2 + target_y_interp**2)**(0.5)
        predicted_displacement_resultant = (pred_x_interp**2 + pred_y_interp**2)**(0.5)
        X_fine_sc = X_fine + scale_factor * target_x_interp
        Y_fine_sc = Y_fine + scale_factor * target_y_interp

        # True X-Displacement
        ax = fig.add_subplot(2, 4, 2)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, target_x_interp, shading='auto', cmap='jet')
        ax.set_aspect('equal')
        ax.set_title('True X-Displacement', fontsize=14, fontweight='bold', pad=10)  # Title padding
        ax.set_ylabel('Width (m)', fontsize=12, labelpad=10)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.2)

        # Predicted X-Displacement
        ax = fig.add_subplot(2, 4, 3)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, pred_x_interp, shading='auto', cmap='jet')
        ax.set_aspect('equal')
        ax.set_title('Predicted X-Displacement', fontsize=14, fontweight='bold', pad=10)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.2)

        # X-Displacement Error with SymLogNorm
        ax = fig.add_subplot(2, 4, 4)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, error_x_interp, shading='auto', cmap='coolwarm', norm=SymLogNorm(linthresh=0.03))
        ax.set_aspect('equal')
        ax.set_title('X-Displacement Error', fontsize=14, fontweight='bold', pad=10)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.2)

        # True Y-Displacement
        ax = fig.add_subplot(2, 4, 6)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, target_y_interp, shading='auto', cmap='jet')
        ax.set_aspect('equal')
        ax.set_title('True Y-Displacement', fontsize=14, fontweight='bold', pad=10)
        ax.set_xlabel('Length (m)', fontsize=12, labelpad=3)
        ax.set_ylabel('Width (m)', fontsize=12, labelpad=10)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.28)

        # Predicted Y-Displacement
        ax = fig.add_subplot(2, 4, 7)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, pred_y_interp, shading='auto', cmap='jet')
        ax.set_aspect('equal')
        ax.set_title('Predicted Y-Displacement', fontsize=14, fontweight='bold', pad=10)
        ax.set_xlabel('Length (m)', fontsize=12, labelpad=3)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.28)

        # Y-Displacement Error with SymLogNorm
        ax = fig.add_subplot(2, 4, 8)
        im = ax.pcolormesh(X_fine_sc, Y_fine_sc, error_y_interp, shading='auto', cmap='coolwarm', norm=SymLogNorm(linthresh=0.03))
        ax.set_aspect('equal')
        ax.set_title('Y-Displacement Error', fontsize=14, fontweight='bold', pad=10)
        ax.set_xlabel('Length (m)', fontsize=12, labelpad=3)
        plt.colorbar(im, ax=ax, orientation='horizontal', pad=0.28)
                
        if save == True:
            plt.savefig(os.path.join(resultdir,'Test_Sample_'+str(i+1)+'.pdf'))
            plt.show()
            plt.close()
        if save == False:
            plt.show()

        print(colored('#'*230, 'green'))

mse_ef = sum(mse_list_x) / len(mse_list_x)
print("Mean Squared Error Test (X-Displacement):\n", mse_ef)
mse_mech = sum(mse_list_y) / len(mse_list_y)
print("Mean Squared Error Test (Y-Displacement):\n", mse_mech)
# Out:
# TEST SAMPLE 10
# Rel. L2 Error (X-Displacement) = 0.0057, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0043, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 20
# Rel. L2 Error (X-Displacement) = 0.0078, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0036, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 30
# Rel. L2 Error (X-Displacement) = 0.0062, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0034, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 40
# Rel. L2 Error (X-Displacement) = 0.0057, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0035, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 50
# Rel. L2 Error (X-Displacement) = 0.0078, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0051, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 60
# Rel. L2 Error (X-Displacement) = 0.0133, R2 score (X-Displacement) = 0.9998
# Rel. L2 Error (Y-Displacement) = 0.0034, R2 score (Y-Displacement) = 0.9999
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 70
# Rel. L2 Error (X-Displacement) = 0.0081, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0031, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 80
# Rel. L2 Error (X-Displacement) = 0.0059, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0027, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 90
# Rel. L2 Error (X-Displacement) = 0.0073, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0042, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 100
# Rel. L2 Error (X-Displacement) = 0.0078, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0043, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 110
# Rel. L2 Error (X-Displacement) = 0.005, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0034, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 120
# Rel. L2 Error (X-Displacement) = 0.0145, R2 score (X-Displacement) = 0.9998
# Rel. L2 Error (Y-Displacement) = 0.0043, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 130
# Rel. L2 Error (X-Displacement) = 0.0069, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0036, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 140
# Rel. L2 Error (X-Displacement) = 0.0051, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0034, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 150
# Rel. L2 Error (X-Displacement) = 0.0113, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0042, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 160
# Rel. L2 Error (X-Displacement) = 0.0038, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0022, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 170
# Rel. L2 Error (X-Displacement) = 0.0105, R2 score (X-Displacement) = 0.9999
# Rel. L2 Error (Y-Displacement) = 0.0035, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 180
# Rel. L2 Error (X-Displacement) = 0.0053, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0035, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 190
# Rel. L2 Error (X-Displacement) = 0.0063, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0034, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# TEST SAMPLE 200
# Rel. L2 Error (X-Displacement) = 0.0045, R2 score (X-Displacement) = 1.0
# Rel. L2 Error (Y-Displacement) = 0.0026, R2 score (Y-Displacement) = 1.0
# ######################################################################################################################################################################################################################################
# Mean Squared Error Test (X-Displacement):
#  6.52236174580878e-08
# Mean Squared Error Test (Y-Displacement):
#  4.0805381738451276e-07
